# %% [markdown]
# # Scraping Random Sample: 500 Songs
# - This notebook outlines the process of scraping 500 songs from the website https://random-song.com/.
# - The output, rand_samp, is a list of songs, which is stored as a notebook wide variable.

# %% [markdown]
# ## Scraping using Selenium

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time

# Path for driver. Only works on mac-arm64. Other machines will have to replace the driver. 
service = Service('./chrome_driver/chromedriver')

# Set up driver
driver = webdriver.Chrome(service=service)

# Open the website
driver.get('https://random-song.com/')

# Get the song button element
get_song_button = driver.find_element(By.ID, 'getTrackButton')

# Click on the song button element 500 times, adding song name and artist to list each time
rand_samp = []
for i in range(1000):
    get_song_button.click()
    track_name = driver.find_element(By.ID, 'trackName').text
    rand_samp.append(track_name)
    time.sleep(1)

# %% [markdown]
# - The initial scraper was successful, and the song titles are listed and stored below.

# %%
# Store rand_samp
print(rand_samp)
# %store rand_samp
# Out:
# ['', 'Lekhara - Khara', 'The Seed - Edit', 'Lady Marian (2003 - Remaster)', 'Empires Lost to Time', 'Digane - Raphael Afro Vibe Remix Extended', 'How He Works (feat. Nico Vega) - Coflo Remix', 'no song found', 'Dia Perfeito', 'A State of Trance (ASOT 1183) - New Scoops!', 'Flame In My Heart', 'By the Sea - Live', 'Laugh Track (feat. Phoebe Bridgers)', "Ok, Let's Roll", 'Canção pra Tua Glória', 'no song found', "You're Gonna Cry", 'Oh Eesa - Club Mix', "L'œuf", 'leave me in the dark', 'no song found', 'One Day Star', 'アダムの林檎 (LPバージョン)', 'Two Zips', 'Heaven & Earth - Radio Edit', 'no song found', 'no song found', 'Amiga', 'Can’t Stop', 'Express Yourself - Terrence Parker Remix', 'Gallons', 'What Have You Got Planned Tonight Diana', 'A ver qué pasa - Estrella Damm 2021', 'The Name of Life (Piano Solo)', 'An Act Of God', '不可能失眠', 'no song found', 'Lama Nas Ruas - Ao Vivo', 'Ekhal na jarmarku (as a merry merchant rode to the fair)', 'The End - Remastered 2009', "切り札を探せ - Live at 横浜スタジア
# ...
